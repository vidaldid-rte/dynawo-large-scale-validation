# %%
# Case selection (adapt CRV_DIR as needed)
CRV_DIR = "PLACEHOLDER_CRV_DIR"
PREFIX = "PLACEHOLDER_PREFIX"
IS_DWO_DWO = PLACEHOLDER_IS_DWO_DWO

# %%
# Tunable parameters and thresholds
MATCH_CRV_AT_PRECONTG_TIME = (
    290  # time at which curves are matched via a Y-offset (use 0 or None to disable)
)
V_THRESH = 0.01  # in p.u.
K_THRESH = 0.1  # in K-level units
P_THRESH = 5  # in MW
Q_THRESH = 10  # in MW

# %%
from dynawo_validation.dynawaltz.notebooks.simulator_A_vs_simulator_B_maincode import (
    main,
)

main(
    CRV_DIR,
    PREFIX,
    IS_DWO_DWO,
    MATCH_CRV_AT_PRECONTG_TIME,
    V_THRESH,
    K_THRESH,
    P_THRESH,
    Q_THRESH,
)
